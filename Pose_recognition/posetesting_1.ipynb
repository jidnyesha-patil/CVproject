# %%
import mediapipe as mp
import cv2
import csv
import os
import numpy as np
import csv
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline 
from sklearn.preprocessing import StandardScaler 

from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import accuracy_score
import pickle 
mp_drawing = mp.solutions.drawing_utils
mp_holistic = mp.solutions.holistic

# %%
with open('body_language_rf.pkl', 'rb') as f:
    model = pickle.load(f)

# %%
model
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('randomforestclassifier', RandomForestClassifier())])

# %%
cap = cv2.VideoCapture('amey1.avi')
#cap = cv2.VideoCapture(0)

with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        

        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        results = holistic.process(image)
       
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
   
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )


        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )


        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )

        try:
     
            pose = results.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())
            

            face = results.face_landmarks.landmark
            face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())
            

            row = pose_row+face_row
            

            X = pd.DataFrame([row])
            body_language_class = model.predict(X)[0]
            body_language_prob = model.predict_proba(X)[0]
            print(body_language_class, body_language_prob)

            coords = tuple(np.multiply(
                            np.array(
                                (results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x, 
                                 results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y))
                        , [640,480]).astype(int))
            
            cv2.rectangle(image, 
                          (coords[0], coords[1]+5), 
                          (coords[0]+len(body_language_class)*20, coords[1]-30), 
                          (245, 117, 16), -1)
            cv2.putText(image, body_language_class, coords, 
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
 
            cv2.rectangle(image, (0,0), (250, 60), (245, 117, 16), -1)
            

            cv2.putText(image, 'CLASS'
                        , (95,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, body_language_class.split(' ')[0]
                        , (90,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
         
            cv2.putText(image, 'PROB'
                        , (15,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, str(round(body_language_prob[np.argmax(body_language_prob)],2))
                        , (10,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
        except:
            pass
                        
        cv2.imshow('data', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# distracted [0.81 0.11 0.08]
# distracted [0.8  0.12 0.08]
# distracted [0.81 0.11 0.08]
# distracted [0.81 0.11 0.08]
# distracted [0.81 0.11 0.08]
# distracted [0.81 0.12 0.07]
# distracted [0.81 0.11 0.08]
# distracted [0.81 0.11 0.08]
# distracted [0.81 0.11 0.08]
# distracted [0.8  0.12 0.08]
# distracted [0.81 0.11 0.08]
# distracted [0.81 0.11 0.08]
# distracted [0.8  0.12 0.08]
# distracted [0.81 0.11 0.08]
# distracted [0.81 0.11 0.08]
# distracted [0.81 0.1  0.09]
# distracted [0.8  0.12 0.08]
# distracted [0.81 0.11 0.08]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.11 0.08]
# distracted [0.81 0.11 0.08]
# distracted [0.81 0.11 0.08]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.11 0.08]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.79 0.12 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.8  0.12 0.08]
# distracted [0.8  0.11 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.77 0.14 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.79 0.12 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.79 0.12 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.79 0.12 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.8  0.12 0.08]
# distracted [0.8  0.11 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.79 0.12 0.09]
# distracted [0.78 0.13 0.09]
# distracted [0.78 0.11 0.11]
# distracted [0.76 0.13 0.11]
# distracted [0.79 0.1  0.11]
# distracted [0.8  0.11 0.09]
# distracted [0.78 0.13 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.78 0.13 0.09]
# distracted [0.78 0.13 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.77 0.14 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.79 0.12 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.77 0.14 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.79 0.12 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.79 0.12 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.79 0.12 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.78 0.13 0.09]
# distracted [0.79 0.12 0.09]
# distracted [0.79 0.12 0.09]
# distracted [0.78 0.13 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.11 0.08]
# distracted [0.81 0.11 0.08]
# distracted [0.81 0.11 0.08]
# distracted [0.81 0.11 0.08]
# distracted [0.79 0.13 0.08]
# distracted [0.8  0.12 0.08]
# distracted [0.71 0.22 0.07]
# distracted [0.48 0.41 0.11]
# distracted [0.54 0.37 0.09]
# distracted [0.52 0.39 0.09]
# distracted [0.56 0.36 0.08]
# distracted [0.53 0.38 0.09]
# distracted [0.57 0.35 0.08]
# distracted [0.58 0.34 0.08]
# distracted [0.67 0.27 0.06]
# distracted [0.52 0.39 0.09]
# distracted [0.51 0.41 0.08]
# distracted [0.52 0.4  0.08]
# distracted [0.49 0.43 0.08]
# distracted [0.55 0.38 0.07]
# distracted [0.54 0.39 0.07]
# distracted [0.55 0.39 0.06]
# distracted [0.57 0.37 0.06]
# distracted [0.54 0.39 0.07]
# distracted [0.54 0.39 0.07]
# distracted [0.51 0.41 0.08]
# distracted [0.51 0.41 0.08]
# distracted [0.52 0.4  0.08]
# distracted [0.53 0.39 0.08]
# distracted [0.54 0.39 0.07]
# distracted [0.54 0.38 0.08]
# distracted [0.57 0.37 0.06]
# distracted [0.54 0.38 0.08]
# distracted [0.54 0.39 0.07]
# distracted [0.48 0.44 0.08]
# distracted [0.49 0.43 0.08]
# distracted [0.5  0.42 0.08]
# distracted [0.51 0.41 0.08]
# distracted [0.49 0.43 0.08]
# distracted [0.5  0.42 0.08]
# distracted [0.53 0.39 0.08]
# distracted [0.53 0.39 0.08]
# distracted [0.53 0.39 0.08]
# distracted [0.51 0.41 0.08]
# distracted [0.51 0.41 0.08]
# distracted [0.51 0.41 0.08]
# distracted [0.53 0.39 0.08]
# distracted [0.51 0.42 0.07]
# distracted [0.51 0.41 0.08]
# distracted [0.51 0.42 0.07]
# distracted [0.53 0.4  0.07]
# distracted [0.56 0.37 0.07]
# distracted [0.52 0.4  0.08]
# distracted [0.56 0.38 0.06]
# distracted [0.59 0.34 0.07]
# distracted [0.56 0.37 0.07]
# distracted [0.57 0.35 0.08]
# distracted [0.58 0.35 0.07]
# distracted [0.55 0.38 0.07]
# distracted [0.55 0.38 0.07]
# distracted [0.54 0.39 0.07]
# distracted [0.61 0.33 0.06]
# distracted [0.57 0.36 0.07]
# distracted [0.58 0.35 0.07]
# distracted [0.57 0.37 0.06]
# distracted [0.53 0.39 0.08]
# distracted [0.6  0.33 0.07]
# distracted [0.53 0.39 0.08]
# distracted [0.54 0.38 0.08]
# distracted [0.55 0.37 0.08]
# distracted [0.56 0.37 0.07]
# distracted [0.57 0.37 0.06]
# distracted [0.55 0.37 0.08]
# distracted [0.55 0.37 0.08]
# distracted [0.52 0.39 0.09]
# distracted [0.54 0.39 0.07]
# distracted [0.58 0.36 0.06]
# distracted [0.56 0.37 0.07]
# distracted [0.61 0.34 0.05]
# distracted [0.62 0.32 0.06]
# distracted [0.65 0.31 0.04]
# distracted [0.6  0.33 0.07]
# distracted [0.63 0.31 0.06]
# distracted [0.57 0.36 0.07]
# distracted [0.59 0.34 0.07]
# distracted [0.58 0.36 0.06]
# distracted [0.63 0.31 0.06]
# distracted [0.59 0.33 0.08]
# distracted [0.58 0.35 0.07]
# distracted [0.6  0.33 0.07]
# distracted [0.61 0.31 0.08]
# distracted [0.59 0.33 0.08]
# distracted [0.6  0.33 0.07]
# distracted [0.64 0.31 0.05]
# distracted [0.63 0.31 0.06]
# distracted [0.66 0.29 0.05]
# distracted [0.64 0.31 0.05]
# distracted [0.67 0.28 0.05]
# distracted [0.61 0.31 0.08]
# distracted [0.68 0.28 0.04]
# distracted [0.71 0.24 0.05]
# distracted [0.68 0.27 0.05]
# distracted [0.57 0.35 0.08]
# distracted [0.69 0.25 0.06]
# distracted [0.6  0.33 0.07]
# distracted [0.53 0.38 0.09]
# distracted [0.52 0.39 0.09]
# distracted [0.52 0.38 0.1 ]
# distracted [0.59 0.34 0.07]
# distracted [0.75 0.19 0.06]
# distracted [0.81 0.14 0.05]
# distracted [0.81 0.11 0.08]
# distracted [0.81 0.11 0.08]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.09 0.1 ]
# distracted [0.81 0.09 0.1 ]
# distracted [0.81 0.09 0.1 ]
# distracted [0.81 0.09 0.1 ]
# distracted [0.81 0.09 0.1 ]
# distracted [0.81 0.09 0.1 ]
# distracted [0.81 0.09 0.1 ]
# distracted [0.83 0.09 0.08]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.83 0.09 0.08]
# distracted [0.83 0.09 0.08]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.83 0.09 0.08]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.83 0.09 0.08]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.83 0.09 0.08]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.83 0.09 0.08]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.83 0.09 0.08]
# distracted [0.83 0.09 0.08]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.83 0.09 0.08]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.82 0.1  0.08]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.09 0.1 ]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.73 0.14 0.13]
# distracted [0.75 0.12 0.13]
# distracted [0.75 0.12 0.13]
# distracted [0.7  0.17 0.13]
# distracted [0.68 0.17 0.15]
# distracted [0.65 0.2  0.15]
# distracted [0.66 0.19 0.15]
# distracted [0.66 0.19 0.15]
# distracted [0.67 0.18 0.15]
# distracted [0.66 0.17 0.17]
# distracted [0.64 0.19 0.17]
# distracted [0.64 0.18 0.18]
# distracted [0.65 0.19 0.16]
# distracted [0.63 0.2  0.17]
# distracted [0.66 0.17 0.17]
# distracted [0.65 0.18 0.17]
# distracted [0.51 0.29 0.2 ]
# distracted [0.56 0.24 0.2 ]
# distracted [0.57 0.25 0.18]
# distracted [0.66 0.18 0.16]
# distracted [0.64 0.19 0.17]
# distracted [0.55 0.27 0.18]
# distracted [0.55 0.26 0.19]
# distracted [0.55 0.27 0.18]
# distracted [0.63 0.19 0.18]
# distracted [0.58 0.22 0.2 ]
# distracted [0.56 0.25 0.19]
# distracted [0.64 0.19 0.17]
# distracted [0.54 0.27 0.19]
# distracted [0.56 0.24 0.2 ]
# distracted [0.62 0.2  0.18]
# distracted [0.53 0.25 0.22]
# distracted [0.64 0.19 0.17]
# distracted [0.63 0.19 0.18]
# distracted [0.65 0.18 0.17]
# distracted [0.62 0.19 0.19]
# distracted [0.57 0.23 0.2 ]
# distracted [0.63 0.19 0.18]
# distracted [0.63 0.19 0.18]
# distracted [0.61 0.19 0.2 ]
# distracted [0.47 0.32 0.21]
# distracted [0.57 0.23 0.2 ]
# distracted [0.46 0.32 0.22]
# distracted [0.6 0.2 0.2]
# distracted [0.53 0.26 0.21]
# distracted [0.61 0.19 0.2 ]
# distracted [0.49 0.29 0.22]
# distracted [0.54 0.27 0.19]
# distracted [0.55 0.25 0.2 ]
# distracted [0.6  0.21 0.19]
# distracted [0.54 0.26 0.2 ]
# distracted [0.56 0.25 0.19]
# distracted [0.52 0.27 0.21]
# distracted [0.48 0.3  0.22]
# distracted [0.52 0.26 0.22]
# distracted [0.6  0.21 0.19]
# distracted [0.5 0.3 0.2]
# distracted [0.5 0.3 0.2]
# distracted [0.55 0.25 0.2 ]
# distracted [0.45 0.36 0.19]
# distracted [0.48 0.3  0.22]
# distracted [0.46 0.32 0.22]
# distracted [0.48 0.3  0.22]
# distracted [0.51 0.29 0.2 ]
# distracted [0.47 0.32 0.21]
# distracted [0.52 0.28 0.2 ]
# distracted [0.43 0.35 0.22]
# distracted [0.47 0.32 0.21]
# distracted [0.47 0.32 0.21]
# distracted [0.46 0.32 0.22]
# distracted [0.48 0.31 0.21]
# distracted [0.52 0.27 0.21]
# distracted [0.43 0.34 0.23]
# distracted [0.49 0.31 0.2 ]
# distracted [0.5  0.29 0.21]
# distracted [0.43 0.34 0.23]
# distracted [0.42 0.34 0.24]
# distracted [0.51 0.26 0.23]
# distracted [0.42 0.34 0.24]
# distracted [0.43 0.33 0.24]
# distracted [0.53 0.25 0.22]
# distracted [0.48 0.29 0.23]
# distracted [0.46 0.3  0.24]
# distracted [0.49 0.27 0.24]
# distracted [0.51 0.29 0.2 ]
# distracted [0.5  0.29 0.21]
# distracted [0.5  0.29 0.21]
# distracted [0.58 0.21 0.21]
# distracted [0.46 0.33 0.21]
# distracted [0.55 0.25 0.2 ]
# distracted [0.4  0.35 0.25]
# distracted [0.46 0.29 0.25]
# distracted [0.49 0.27 0.24]
# distracted [0.48 0.29 0.23]
# distracted [0.47 0.3  0.23]
# distracted [0.4  0.35 0.25]
# distracted [0.45 0.31 0.24]
# distracted [0.47 0.3  0.23]
# distracted [0.4  0.34 0.26]
# distracted [0.39 0.35 0.26]
# distracted [0.4  0.36 0.24]
# distracted [0.56 0.24 0.2 ]
# distracted [0.64 0.18 0.18]
# distracted [0.73 0.13 0.14]
# distracted [0.74 0.1  0.16]
# distracted [0.76 0.09 0.15]
# distracted [0.79 0.09 0.12]
# distracted [0.79 0.09 0.12]
# distracted [0.8  0.07 0.13]
# distracted [0.8  0.07 0.13]
# distracted [0.8  0.08 0.12]
# distracted [0.79 0.09 0.12]
# distracted [0.8  0.08 0.12]
# distracted [0.78 0.09 0.13]
# distracted [0.8  0.07 0.13]
# distracted [0.79 0.09 0.12]
# distracted [0.75 0.09 0.16]
# distracted [0.78 0.09 0.13]
# distracted [0.79 0.09 0.12]
# distracted [0.78 0.09 0.13]
# distracted [0.79 0.09 0.12]
# distracted [0.79 0.09 0.12]
# distracted [0.79 0.09 0.12]
# distracted [0.8  0.08 0.12]
# distracted [0.79 0.09 0.12]
# distracted [0.79 0.09 0.12]
# distracted [0.79 0.09 0.12]
# distracted [0.78 0.1  0.12]
# distracted [0.78 0.1  0.12]
# distracted [0.79 0.1  0.11]
# distracted [0.8  0.11 0.09]
# distracted [0.8 0.1 0.1]
# distracted [0.8  0.11 0.09]
# distracted [0.81 0.09 0.1 ]
# distracted [0.8  0.08 0.12]
# distracted [0.79 0.1  0.11]
# distracted [0.79 0.1  0.11]
# distracted [0.79 0.1  0.11]
# distracted [0.79 0.09 0.12]
# distracted [0.79 0.1  0.11]
# distracted [0.79 0.1  0.11]
# distracted [0.79 0.1  0.11]
# distracted [0.79 0.1  0.11]
# distracted [0.79 0.1  0.11]
# distracted [0.79 0.1  0.11]
# distracted [0.79 0.1  0.11]
# distracted [0.79 0.1  0.11]
# distracted [0.79 0.1  0.11]
# distracted [0.79 0.1  0.11]
# distracted [0.79 0.1  0.11]
# distracted [0.79 0.1  0.11]
# distracted [0.79 0.11 0.1 ]
# distracted [0.79 0.11 0.1 ]
# distracted [0.79 0.11 0.1 ]
# distracted [0.8  0.12 0.08]
# distracted [0.81 0.1  0.09]
# distracted [0.8 0.1 0.1]
# distracted [0.8  0.11 0.09]
# distracted [0.8  0.11 0.09]
# distracted [0.81 0.1  0.09]
# distracted [0.8 0.1 0.1]
# distracted [0.8 0.1 0.1]
# distracted [0.8 0.1 0.1]
# distracted [0.79 0.09 0.12]
# distracted [0.78 0.1  0.12]
# distracted [0.79 0.09 0.12]
# distracted [0.79 0.1  0.11]
# distracted [0.78 0.1  0.12]
# distracted [0.74 0.11 0.15]
# distracted [0.77 0.1  0.13]
# distracted [0.77 0.08 0.15]
# distracted [0.77 0.1  0.13]
# distracted [0.79 0.08 0.13]
# distracted [0.76 0.09 0.15]
# distracted [0.79 0.08 0.13]
# distracted [0.79 0.09 0.12]
# distracted [0.79 0.09 0.12]
# distracted [0.78 0.08 0.14]
# distracted [0.77 0.09 0.14]
# distracted [0.76 0.09 0.15]
# distracted [0.75 0.1  0.15]
# distracted [0.75 0.1  0.15]
# distracted [0.7  0.14 0.16]
# distracted [0.75 0.1  0.15]
# distracted [0.79 0.09 0.12]
# distracted [0.79 0.1  0.11]
# distracted [0.78 0.1  0.12]
# distracted [0.76 0.12 0.12]
# distracted [0.74 0.11 0.15]
# distracted [0.72 0.11 0.17]
# distracted [0.7  0.14 0.16]
# distracted [0.69 0.16 0.15]
# distracted [0.69 0.15 0.16]
# distracted [0.63 0.18 0.19]
# distracted [0.68 0.14 0.18]
# distracted [0.67 0.15 0.18]
# distracted [0.6 0.2 0.2]
# distracted [0.6  0.21 0.19]
# distracted [0.6  0.21 0.19]
# distracted [0.56 0.21 0.23]
# distracted [0.56 0.18 0.26]
# distracted [0.55 0.2  0.25]
# distracted [0.56 0.2  0.24]
# distracted [0.54 0.21 0.25]
# distracted [0.55 0.2  0.25]
# distracted [0.56 0.21 0.23]
# distracted [0.51 0.24 0.25]
# distracted [0.45 0.27 0.28]
# distracted [0.56 0.22 0.22]
# distracted [0.45 0.27 0.28]
# distracted [0.53 0.22 0.25]
# distracted [0.44 0.3  0.26]
# distracted [0.49 0.22 0.29]
# distracted [0.52 0.22 0.26]
# distracted [0.54 0.22 0.24]
# distracted [0.54 0.21 0.25]
# distracted [0.54 0.21 0.25]
# distracted [0.55 0.2  0.25]
# distracted [0.56 0.19 0.25]
# distracted [0.52 0.25 0.23]
# distracted [0.5  0.27 0.23]
# distracted [0.57 0.18 0.25]
# distracted [0.42 0.34 0.24]
# distracted [0.42 0.32 0.26]
# distracted [0.45 0.29 0.26]
# distracted [0.36 0.36 0.28]
# distracted [0.41 0.34 0.25]
# distracted [0.5  0.23 0.27]
# distracted [0.34 0.34 0.32]
# distracted [0.42 0.31 0.27]
# distracted [0.39 0.32 0.29]
# distracted [0.4  0.33 0.27]
# distracted [0.38 0.36 0.26]
# distracted [0.4  0.32 0.28]
# distracted [0.41 0.33 0.26]
# distracted [0.35 0.35 0.3 ]
# distracted [0.41 0.31 0.28]
# distracted [0.42 0.34 0.24]
# lookinghereandthere [0.32 0.35 0.33]
# distracted [0.35 0.35 0.3 ]
# lookinghereandthere [0.3  0.38 0.32]
# lookinghereandthere [0.32 0.37 0.31]
# lookinghereandthere [0.31 0.38 0.31]
# lookinghereandthere [0.33 0.38 0.29]
# lookinghereandthere [0.27 0.39 0.34]
# lookinghereandthere [0.27 0.4  0.33]
# lookinghereandthere [0.28 0.36 0.36]
# lookinghereandthere [0.27 0.4  0.33]
# lookinghereandthere [0.29 0.37 0.34]
# lookinghereandthere [0.3  0.38 0.32]
# lookinghereandthere [0.3  0.35 0.35]
# lookinghereandthere [0.3  0.37 0.33]
# lookinghereandthere [0.3  0.37 0.33]
# lookinghereandthere [0.27 0.39 0.34]
# lookinghereandthere [0.27 0.41 0.32]
# lookinghereandthere [0.26 0.42 0.32]
# lookinghereandthere [0.26 0.42 0.32]
# lookinghereandthere [0.25 0.44 0.31]
# lookinghereandthere [0.26 0.41 0.33]
# lookinghereandthere [0.25 0.43 0.32]
# lookinghereandthere [0.29 0.39 0.32]
# lookinghereandthere [0.29 0.39 0.32]
# lookinghereandthere [0.25 0.43 0.32]
# lookinghereandthere [0.27 0.43 0.3 ]
# lookinghereandthere [0.28 0.38 0.34]
# lookinghereandthere [0.25 0.41 0.34]
# lookinghereandthere [0.27 0.37 0.36]
# lookinghereandthere [0.25 0.43 0.32]
# lookinghereandthere [0.21 0.44 0.35]
# lookinghereandthere [0.25 0.42 0.33]
# lookinghereandthere [0.26 0.4  0.34]
# lookinghereandthere [0.27 0.41 0.32]
# lookinghereandthere [0.3  0.39 0.31]
# lookinghereandthere [0.26 0.37 0.37]
# lookinghereandthere [0.26 0.4  0.34]
# lookinghereandthere [0.26 0.4  0.34]
# lookinghereandthere [0.25 0.42 0.33]
# lookinghereandthere [0.24 0.42 0.34]
# lookinghereandthere [0.27 0.4  0.33]
# lookinghereandthere [0.25 0.43 0.32]
# lookinghereandthere [0.27 0.42 0.31]
# lookinghereandthere [0.24 0.42 0.34]
# lookinghereandthere [0.23 0.44 0.33]
# lookinghereandthere [0.2  0.46 0.34]
# lookinghereandthere [0.26 0.42 0.32]
# lookinghereandthere [0